# %%
#Membuat list awal
kendaraan = ['namakendaraan', 'JenisKendaraan', 'cckendaraan' 'warnakendaraan' 'rodakendaraan']

#Menambahkan 'merk kendaraan' setelah 'Jeniskendaraan'
kendaraan.insert(2, 'merk kendaraan')

#Menambahkan 'harga kendaraan' dan 'tipe kendaraan' di belakang list
kendaraan.extend(['harga kendaraan', 'tipe kendaraan'])

#Menampilkan hasil
print(kendaraan)
# Out:
# ['namakendaraan', 'JenisKendaraan', 'merk kendaraan', 'cckendaraanwarnakendaraanrodakendaraan', 'harga kendaraan', 'tipe kendaraan']

# %%
pilih = int(input("""selamat datang diaplikasi menghitung
1. untuk menghitung luas persegi
2. untuk menghitung luas lingkaran
3. untuk menghitung luas segitiga \n"""))

match pilih:
     case 1 :
         print("kamu memilih 1 untuk menghitung luas persegi")
         sisi = int(input("masukkan jari-jari: "))
         luaspersegi = sisi*sisi
         print("luas persegi yang sisinya",sisi, "adalah", luaspersegi)
     case 2 :
         print("kamu memilih 2 untuk menghitung lingkaran")
         jari2 = int(input("masukkan sisi persegi: "))
         luaslingkaran = 3.14*jari2*jari2
         print("luas persegi yang sisinya",jari2, "adalah", luaslingkaran)
     case 3 :
         print("kamu memilih 3 untuk menghitung segitiga")
         alas = int(input("masukkan alas segitiga: "))
         tinggi = int(input("masukkan tinggi segitiga: "))
         luasSegitiga = 0.5*alas*tinggi
         print("luas segitiga dengan alas",alas, "dan tinggi",tinggi, "adalah", luaslingkaran)
     case _:
           print("anda salah pilih")
# Out:
# selamat datang diaplikasi menghitung
# 1. untuk menghitung luas persegi
# 2. untuk menghitung luas lingkaran
# 3. untuk menghitung luas segitiga
# 2
# kamu memilih 2 untuk menghitung lingkaran
# masukkan sisi persegi: 21
# luas persegi yang sisinya 21 adalah 1384.74
